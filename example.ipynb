# %%
import fmt
import utils

# %%
map_design = utils.load_map_design("maps/0.png")

planner = fmt.FMTPlanner(map_design, 1000, 5, 0.1, 1.0, 1000)
# %time path_info = planner.plan([4, 60], [60, 4])
utils.visualize_result(map_design, planner, path_info)

# using Euclidean heuristics
# %time path_info = planner.plan([4, 60], [60, 4], heuristic_weight=1.0)
utils.visualize_result(map_design, planner, path_info)
# Out:
# Reached goal
# CPU times: user 347 ms, sys: 330 µs, total: 348 ms
# Wall time: 351 ms
# Reached goal
# CPU times: user 281 ms, sys: 66.5 ms, total: 348 ms
# Wall time: 250 ms

# %%
map_design = utils.load_map_design("maps/1.png")

planner = fmt.FMTPlanner(map_design, 1000, 5, 0.1, 1.0, 1000)
# %time path_info = planner.plan([4, 60], [60, 4])
utils.visualize_result(map_design, planner, path_info)


# using Euclidean heuristics
# %time path_info = planner.plan([4, 60], [60, 4], heuristic_weight=1.0)
utils.visualize_result(map_design, planner, path_info)
# Out:
# Reached goal
# CPU times: user 365 ms, sys: 0 ns, total: 365 ms
# Wall time: 367 ms
# Reached goal
# CPU times: user 326 ms, sys: 71.6 ms, total: 398 ms
# Wall time: 297 ms
